# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.4.9-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: numpy>=1.23.0 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: matplotlib>=3.3.0 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from ultralytics) (3.10.8)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Downloading opencv_python-4.13.0.90-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from ultralytics) (12.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from ultralytics) (1.17.0)
# Requirement already satisfied: torch>=1.8.0 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from ultralytics) (2.10.0)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.25.0-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: psutil>=5.8.0 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from ultralytics) (7.2.2)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.37.1-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.37.1 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.37.1-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.1.0)
# Requirement already satisfied: setuptools in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (80.10.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\vs_code\21_days_21_projects_ai_ml\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.9-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 12.9 MB/s  0:00:00
# Downloading opencv_python-4.13.0.90-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    --- ------------------------------------ 3.7/40.2 MB 17.9 MB/s eta 0:00:03
#    ------ --------------------------------- 6.3/40.2 MB 14.4 MB/s eta 0:00:03
#    -------- ------------------------------- 8.4/40.2 MB 13.2 MB/s eta 0:00:03
#    --------- ------------------------------ 10.0/40.2 MB 11.4 MB/s eta 0:00:03
#    ------------ --------------------------- 12.3/40.2 MB 11.5 MB/s eta 0:00:03
#    --------------- ------------------------ 16.0/40.2 MB 12.4 MB/s eta 0:00:02
#    ------------------- -------------------- 19.4/40.2 MB 12.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 23.1/40.2 MB 13.4 MB/s eta 0:00:02
#    -------------------------- ------------- 26.7/40.2 MB 13.9 MB/s eta 0:00:01
#    ------------------------------ --------- 30.4/40.2 MB 14.2 MB/s eta 0:00:01
#    --------------------------------- ------ 33.8/40.2 MB 14.5 MB/s eta 0:00:01
#    ------------------------------------- -- 37.7/40.2 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 10.0 MB/s  0:00:04
# Downloading polars-1.37.1-py3-none-any.whl (805 kB)
#    ---------------------------------------- 0.0/805.7 kB ? eta -:--:--
#    ---------------------------------------- 805.7/805.7 kB 8.5 MB/s  0:00:00
# Downloading polars_runtime_32-1.37.1-cp310-abi3-win_amd64.whl (44.9 MB)
#    ---------------------------------------- 0.0/44.9 MB ? eta -:--:--
#    --- ------------------------------------ 3.4/44.9 MB 17.4 MB/s eta 0:00:03
#    ------ --------------------------------- 7.1/44.9 MB 17.2 MB/s eta 0:00:03
#    --------- ------------------------------ 10.7/44.9 MB 17.2 MB/s eta 0:00:02
#    ------------ --------------------------- 14.4/44.9 MB 17.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 18.1/44.9 MB 17.2 MB/s eta 0:00:02
#    ------------------- -------------------- 22.0/44.9 MB 17.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 25.7/44.9 MB 17.3 MB/s eta 0:00:02
#    -------------------------- ------------- 29.4/44.9 MB 17.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 33.0/44.9 MB 17.2 MB/s eta 0:00:01
#    -------------------------------- ------- 36.7/44.9 MB 17.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.4/44.9 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.9 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.9 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.9 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.9 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.9 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.9 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------- 44.9/44.9 MB 11.7 MB/s  0:00:03
# Downloading torchvision-0.25.0-cp313-cp313-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    --------------------------------- ------ 3.7/4.3 MB 17.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 16.0 MB/s  0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: polars-runtime-32, opencv-python, polars, ultralytics-thop, torchvision, ultralytics
#
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ------ --------------------------------- 1/6 [opencv-python]
#    ------ --------------------------------- 1/6 [opencv-python]
#    ------ --------------------------------- 1/6 [opencv-python]
#    ------ --------------------------------- 1/6 [opencv-python]
#    ------ --------------------------------- 1/6 [opencv-python]
#    ------ --------------------------------- 1/6 [opencv-python]
#    ------ --------------------------------- 1/6 [opencv-python]
#    ------ --------------------------------- 1/6 [opencv-python]
#    ------ --------------------------------- 1/6 [opencv-python]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    -------------------- ------------------- 3/6 [ultralytics-thop]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    ---------------------------------------- 6/6 [ultralytics]
#
# Successfully installed opencv-python-4.13.0.90 polars-1.37.1 polars-runtime-32-1.37.1 torchvision-0.25.0 ultralytics-8.4.9 ultralytics-thop-2.0.18

# %%
from ultralytics import YOLO
import cv2
# from google.colab.patches import cv2_imshow
import numpy as np

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Open the default camera
cap = cv2.VideoCapture(0)

# Check if camera opened successfully
if not cap.isOpened():
    print("Error: Could not open camera.")
else:
    while True:
        # Read a frame from the camera
        ret, frame = cap.read()

        # If frame is read correctly ret is True
        if not ret:
            print("Error: Can't receive frame (stream end?). Exiting ...")
            break

        # Perform object detection on the frame
        results = model(frame, verbose=False) # Set verbose=False to reduce output

        # Annotate the frame with detection results
        annotated_frame = results[0].plot()
        # Display the annotated frame
        cv2.imshow("YOLOv8 Object Detection", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release the capture and destroy all windows
    cap.release()
    cv2.destroyAllWindows()
